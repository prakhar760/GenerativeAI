# %% [markdown]
# <a href="https://colab.research.google.com/github/prakhar760/TextToImage/blob/main/TextToImageUsingStableDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install libraries
pip install diffusers==0.10.2 transformers scipy ftfy accelerate

# %%
#load and import stable diffusion model
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")

# %%
#for switching to GPU if available
pipe.to("cuda")

# %%
prompt = "a bald guy holding nvidia dgx a100"

image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# you can save the image with
image.save(f"astronaut_rides_horse2.png")

# %%
result = pipe(prompt)
print(result)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# StableDiffusionPipelineOutput(images=[<PIL.Image.Image image mode=RGB size=512x512 at 0x79CB1CFA3CD0>], nsfw_content_detected=[False])

# %%
from PIL import Image

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %%
#to generate multiple images with same prompt combined in a grid
num_images = 3
prompt = ["a bald guy holding jupyter notebook"] * num_images

images = pipe(prompt).images

grid = image_grid(images, rows=1, cols=3)

# you can save the grid with
grid.save(f"astronaut_rides_horse3.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#to generate images with custom size
prompt = "a photograph of an astronaut riding a horse"
image = pipe(prompt, height=512, width=768).images[0]

# you can save the image with
image.save(f"astronaut_rides_horse4.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
